# %%
from evaluation import test

# %%
tests = test.load_tests()

# %%
len(tests)
# Out:
# 150

# %%
example = tests[1]
print(example.question)
print(example.category)
print(example.reference_answer)
print(example.keywords)
# Out:
# When was Insurellm founded?
# direct_fact
# Insurellm was founded in 2015.
# ['2015', 'founded']

# %%
from collections import Counter
count = Counter([t.category for t in tests])
count
# Out:
# Counter({'direct_fact': 70,
#          'temporal': 20,
#          'spanning': 20,
#          'comparative': 10,
#          'numerical': 10,
#          'relationship': 10,
#          'holistic': 10})

# %%
from evaluation.eval import evaluate_retrieval, evaluate_answer

# %%
evaluate_retrieval(example)
# Out:
# RetrievalEval(mrr=1.0, ndcg=0.9197207891481876, keywords_found=2, total_keywords=2, keyword_coverage=100.0)

# %%
eval, answer, chunks = evaluate_answer(example)

# %%
eval
# Out:
# AnswerEval(feedback="The answer correctly states the founding year as 2015, matching the reference answer. It includes an extra detail about the founder, which is additional but doesn't detract from correctness. However, since the question only asked for the founding year, the extra information slightly reduces relevance.", accuracy=5.0, completeness=5.0, relevance=4.0)

# %%
print(eval.feedback)
print(eval.accuracy)
print(eval.completeness)
print(eval.relevance)
# Out:
# The answer correctly states the founding year as 2015, matching the reference answer. It includes an extra detail about the founder, which is additional but doesn't detract from correctness. However, since the question only asked for the founding year, the extra information slightly reduces relevance.
# 5.0
# 5.0
# 4.0
