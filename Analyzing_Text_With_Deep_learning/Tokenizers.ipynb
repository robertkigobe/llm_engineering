# %%
# !pip install transformers datasets sentencepiece einops
# !pip install tiktoken
# Out:
# Requirement already satisfied: transformers in /Applications/anaconda3/lib/python3.8/site-packages (4.46.3)
# Requirement already satisfied: datasets in /Applications/anaconda3/lib/python3.8/site-packages (3.1.0)
# Requirement already satisfied: sentencepiece in /Applications/anaconda3/lib/python3.8/site-packages (0.2.0)
# Requirement already satisfied: einops in /Applications/anaconda3/lib/python3.8/site-packages (0.8.1)
# Requirement already satisfied: pyyaml>=5.1 in /Applications/anaconda3/lib/python3.8/site-packages (from transformers) (5.4.1)
# Requirement already satisfied: requests in /Applications/anaconda3/lib/python3.8/site-packages (from transformers) (2.32.4)
# Requirement already satisfied: safetensors>=0.4.1 in /Applications/anaconda3/lib/python3.8/site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /Applications/anaconda3/lib/python3.8/site-packages (from transformers) (4.67.3)
# Requirement already satisfied: numpy>=1.17 in /Applications/anaconda3/lib/python3.8/site-packages (from transformers) (1.20.1)
# Requirement already satisfied: regex!=2019.12.17 in /Applications/anaconda3/lib/python3.8/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: packaging>=20.0 in /Applications/anaconda3/lib/python3.8/site-packages (from transformers) (20.9)
# Requirement already satisfied: filelock in /Applications/anaconda3/lib/python3.8/site-packages (from transformers) (3.0.12)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /Applications/anaconda3/lib/python3.8/site-packages (from transformers) (0.20.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /Applications/anaconda3/lib/python3.8/site-packages (from transformers) (0.36.2)
# Requirement already satisfied: aiohttp in /Applications/anaconda3/lib/python3.8/site-packages (from datasets) (3.10.11)
# Requirement already satisfied: fsspec[http]<=2024.9.0,>=2023.1.0 in /Applications/anaconda3/lib/python3.8/site-packages (from datasets) (2024.9.0)
# Requirement already satisfied: pandas in /Applications/anaconda3/lib/python3.8/site-packages (from datasets) (1.2.4)
# Requirement already satisfied: xxhash in /Applications/anaconda3/lib/python3.8/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Applications/anaconda3/lib/python3.8/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pyarrow>=15.0.0 in /Applications/anaconda3/lib/python3.8/site-packages (from datasets) (17.0.0)
# Requirement already satisfied: multiprocess<0.70.17 in /Applications/anaconda3/lib/python3.8/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Applications/anaconda3/lib/python3.8/site-packages (from aiohttp->datasets) (5.0.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Applications/anaconda3/lib/python3.8/site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: attrs>=17.3.0 in /Applications/anaconda3/lib/python3.8/site-packages (from aiohttp->datasets) (20.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Applications/anaconda3/lib/python3.8/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Applications/anaconda3/lib/python3.8/site-packages (from aiohttp->datasets) (1.15.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Applications/anaconda3/lib/python3.8/site-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /Applications/anaconda3/lib/python3.8/site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Applications/anaconda3/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Applications/anaconda3/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.13.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /Applications/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->transformers) (2.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Applications/anaconda3/lib/python3.8/site-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Applications/anaconda3/lib/python3.8/site-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Applications/anaconda3/lib/python3.8/site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Applications/anaconda3/lib/python3.8/site-packages (from requests->transformers) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Applications/anaconda3/lib/python3.8/site-packages (from pandas->datasets) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Applications/anaconda3/lib/python3.8/site-packages (from pandas->datasets) (2021.1)
# Requirement already satisfied: six>=1.5 in /Applications/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Requirement already satisfied: propcache>=0.2.0 in /Applications/anaconda3/lib/python3.8/site-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.2.0)
# Requirement already satisfied: tiktoken in /Applications/anaconda3/lib/python3.8/site-packages (0.7.0)
# Requirement already satisfied: regex>=2022.1.18 in /Applications/anaconda3/lib/python3.8/site-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /Applications/anaconda3/lib/python3.8/site-packages (from tiktoken) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Applications/anaconda3/lib/python3.8/site-packages (from requests>=2.26.0->tiktoken) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Applications/anaconda3/lib/python3.8/site-packages (from requests>=2.26.0->tiktoken) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Applications/anaconda3/lib/python3.8/site-packages (from requests>=2.26.0->tiktoken) (2022.12.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Applications/anaconda3/lib/python3.8/site-packages (from requests>=2.26.0->tiktoken) (1.26.4)

# %%
# !pip install pathlib ruamel-yaml
# Out:
# Collecting pathlib
#   Downloading pathlib-1.0.1-py3-none-any.whl (14 kB)
# Collecting ruamel-yaml
#   Downloading ruamel.yaml-0.18.16-py3-none-any.whl (119 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.9/119.9 kB 638.6 kB/s eta 0:00:00a 0:00:01
# Collecting ruamel.yaml.clib>=0.2.7
#   Downloading ruamel.yaml.clib-0.2.8-cp38-cp38-macosx_10_9_x86_64.whl (146 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.2/146.2 kB 1.5 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pathlib, ruamel.yaml.clib, ruamel-yaml
# Successfully installed pathlib-1.0.1 ruamel-yaml-0.18.16 ruamel.yaml.clib-0.2.8

# %%
from transformers import AutoModel, AutoTokenizer

# %%
def show_tokens(sentence, tokenizer_name, print_token_ids = False):
    if tokenizer_name == "gpt-4":
        tokenizer = tiktoken.encoding_for_model("gpt-4")
        token_ids = tokenizer.encode(sentence)
    else:
        tokenizer = AutoTokenizer.from_pretrained(tokenizer_name)
        token_ids = tokenizer(sentence).input_ids

    for t in token_ids:
        if print_token_ids:
            print(t, end=" ")
        print( '\x1b[0;30;47m' + tokenizer.decode([t]) + '\x1b[0m', end = ' ')
    print(t, '\x1b[0;30;47m' + tokenizer.decode([t]) + '\x1b[0m', end = ' ')

# %%
def encode_decode(sentence, tokenizer_name):
    tokenizer = AutoTokenizer.from_pretrained(tokenizer_name)
    token_ids = tokenizer.encode(sentence)
    print(tokenizer.decode(token_ids))

# %%
text = """
    English and CAPITALIZATION
    🙂 好
    show_tokens False None elif == >= else:
    Two tabs: "\t\t" Four spaces: "    "
    12.0*50=600
    """

# %%
show_tokens(text,"bert-base-uncased")
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# [CLS] english and capital ##ization [UNK] [UNK] show _ token ##s false none eli ##f = = > = else : two tab ##s : " " four spaces : " " 12 . 0 * 50 = 600 [SEP] 102 [SEP]

# %%
encode_decode(text,"bert-base-uncased")
# Out:
# [CLS] english and capitalization [UNK] [UNK] show _ tokens false none elif = = > = else : two tabs : " " four spaces : " " 12. 0 * 50 = 600 [SEP]

# %%
show_tokens(text,"bert-base-cased")
# Out:
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# [CLS] English and CA ##PI ##TA ##L ##I ##Z ##AT ##ION [UNK] [UNK] show _ token ##s F ##als ##e None el ##if = = > = else : Two ta ##bs : " " Four spaces : " " 12 . 0 * 50 = 600 [SEP] 102 [SEP]

# %%
encode_decode(text,"bert-base-cased")
# Out:
# [CLS] English and CAPITALIZATION [UNK] [UNK] show _ tokens False None elif = = > = else : Two tabs : " " Four spaces : " " 12. 0 * 50 = 600 [SEP]

# %%
show_tokens(text,"gpt2")
# Out:
#         English  and  CAP ITAL IZ ATION
#         🙂  � � �
#         show _ t ok ens  False  None  el if  ==  >=  else :
#         Two  tabs :  " 	 	 "  Four  spaces :  "        "
#         12 . 0 * 50 = 600
#          220

# %%
encode_decode(text,"bert-base-uncased")
# Out:
# [CLS] english and capitalization [UNK] [UNK] show _ tokens false none elif = = > = else : two tabs : " " four spaces : " " 12. 0 * 50 = 600 [SEP]

# %%
show_tokens(text,"google/flan-t5-small")
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# English and CA PI TAL IZ ATION  <unk>  <unk> show _ to ken s Fal s e None  e l if = = > = else : Two tab s : " " Four spaces : " " 12. 0 * 50 = 600  </s> 1 </s>

# %%
encode_decode(text,"google/flan-t5-small")
# Out:
# English and CAPITALIZATION <unk> <unk> show_tokens False None elif == >= else: Two tabs: " " Four spaces: " " 12.0*50=600 </s>

# %%
show_tokens(text,"facebook/galactica-1.3b")
# Out:
#       English  and  CAP ITAL IZATION
#        � � � �  � � �
#       show _ tokens  False  None  elif   ==   > =  else :
#       Two  t abs :   " 		 "  Four  spaces :   "      "
#       1 2 . 0 * 5 0 = 6 0 0
#       344

# %%
encode_decode(text,"facebook/galactica-1.3b")
# Out:
#     English and CAPITALIZATION
#     🙂 好
#     show_tokens False None elif == >= else:
#     Two tabs: "		" Four spaces: "    "
#     12.0*50=600

# %%
show_tokens(text, "gpt-4")
# Out:
#       English  and  CAPITAL IZATION
#       🙂  � � �
#       show _tokens  False  None  elif  ==  >=  else :
#       Two  tabs :  " 	 	 "  Four  spaces :  "      "
#        12 . 0 * 50 = 600
#       257

# %%
encode_decode(text,"gpt-4")
